# %% [markdown]
# # 선형회귀 모델 실습: Linear Regression simple example

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings

# 경고 메시지 출력 표기 생략
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 샘플에 활용할 데이터 셋 만들기

# %%
def make_linear(w=3, b=5, size=50, noise=1.0):
    x = 4 * np.random.rand(size)
    y = w * x + b
    noise = np.random.uniform(-abs(noise), abs(noise), size=y.shape)
    yy = y + noise
    plt.figure(figsize=(10, 7))
    #plt.plot(x, y, color='r', label=f'y = {w}x + {b}')
    plt.scatter(x, yy, label='data')
    #plt.legend(fontsize=15)
    plt.show()
    print(f'w: {w}, b: {b}')
    return x, yy

# %%
x, y = make_linear(w=2.0, b=5.0, size=100, noise=3.0)
# Out:
# w: 2.0, b: 5.0

# %%
x
x = x.reshape(100,1)

# %%
y
# Out:
# array([ 4.94539596,  6.68998985,  7.16757699,  8.34894947,  6.82979928,
#         6.67470927,  7.6780264 , 10.63494726,  9.1204011 , 10.45668726,
#         6.55778507,  6.45320944,  7.58832081, 14.85248092,  8.96250097,
#        12.61418849,  3.70939112, 12.02868248, 14.35968387,  6.26150931,
#        14.98250523,  8.35941914,  8.84945243, 11.0394606 , 12.59729905,
#        14.49511024,  5.98061894, 11.01326543,  8.86500841,  4.150013  ,
#        13.10632368,  9.56069492, 12.86964547,  6.32760756,  8.03906763,
#         7.66903291,  6.44946753,  8.55845956, 15.36264182,  7.49268224,
#        10.62087847, 11.70488934, 11.45727811,  6.0234204 , 11.52209424,
#        13.03363015,  8.50014675,  6.51753504,  7.78019493, 10.7891287 ,
#        11.10108148,  7.99508571,  8.90632352,  8.70793362,  9.84229494,
#        12.67181806, 15.95793421,  9.47799706, 12.14181381,  9.85892132,
#         8.9742357 ,  7.05017623, 15.28581101, 11.75175733,  7.61243425,
#        10.16154157,  9.71947506,  3.92858407,  7.04750364, 10.71292183,
#         7.60733799, 12.66853764, 12.29326247, 10.86758893,  6.10616436,
#         4.17169732,  9.72782894, 10.93994962,  9.62826487,  9.77961581,
#        12.87066298, 12.32991727,  5.98691744,  8.65833788, 13.07767536,
#         6.1990084 , 10.11121368,  7.4648658 , 14.4058993 , 10.14353139,
#         4.24365975, 12.71767361, 10.00251287,  7.6297385 ,  9.03009231,
#         7.78076304,  6.89698241, 11.46413251, 10.55335029,  9.65163108])

# %% [markdown]
# ## Linear regression 모델 훈련
#
# ## Scikit-learn 라이브러리의 LinearRegression() 사용

# %%
from sklearn.linear_model import LinearRegression

# 선형회귀 모델


# 모델 훈련
# Out:
# LinearRegression()

# %%
# 회귀계수(w)
model.coef_
# Out:
# array([1.97744248])

# %%
# 편향(b) 혹은 y 절편
model.intercept_
# Out:
# 4.98699930006609

# %%
# 예측
y_pred = model.predict(x) 

# 선형 회귀선 그리기
plt.scatter(x, y)
plt.plot(x, y_pred)
