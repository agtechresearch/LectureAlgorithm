# %% [markdown]
# # 선형회귀 모델 실습: Linear Regression simple example

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings

# 경고 메시지 출력 표기 생략
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 샘플에 활용할 데이터 셋 만들기

# %%
def make_linear(w=3, b=5, size=50, noise=1.0):
    x = 4 * np.random.rand(size)
    y = w * x + b
    noise = np.random.uniform(-abs(noise), abs(noise), size=y.shape)
    yy = y + noise
    plt.figure(figsize=(10, 7))
    #plt.plot(x, y, color='r', label=f'y = {w}x + {b}')
    plt.scatter(x, yy, label='data')
    #plt.legend(fontsize=15)
    plt.show()
    print(f'w: {w}, b: {b}')
    return x, yy

# %%
x, y = make_linear(w=2.0, b=5.0, size=100, noise=3.0)
# Out:
# w: 2.0, b: 5.0

# %%
x = x.reshape(100,1)
x
# Out:
# array([[3.91806511],
#        [3.92035203],
#        [0.76425357],
#        [2.48961342],
#        [0.94986715],
#        [0.35813631],
#        [1.67330074],
#        [2.6557352 ],
#        [0.13962095],
#        [1.89271851],
#        [3.56376227],
#        [0.29677456],
#        [3.63385686],
#        [3.08224162],
#        [3.20489201],
#        [2.83144501],
#        [2.1997769 ],
#        [3.2722348 ],
#        [3.94357691],
#        [1.40712421],
#        [2.81332873],
#        [3.08258031],
#        [2.78606887],
#        [1.06776221],
#        [3.71486837],
#        [3.30123406],
#        [3.44387971],
#        [2.21391577],
#        [0.58521669],
#        [2.06706715],
#        [1.60516453],
#        [2.59619282],
#        [1.5948439 ],
#        [2.83390023],
#        [1.02571865],
#        [3.53012567],
#        [1.05465264],
#        [2.83417336],
#        [3.68731011],
#        [0.2050189 ],
#        [2.62444964],
#        [3.60661301],
#        [3.94216572],
# ...

# %%
y
# Out:
# array([10.95402194, 15.03891376,  8.10437671,  8.017667  ,  7.77645741,
#         8.60967751,  7.41054055, 11.99267279,  5.25935014,  8.62094562,
#         9.8918866 ,  5.04790027, 13.95053941, 11.09098423, 10.6914621 ,
#         9.98580761, 10.5600512 , 13.81671021, 13.23533271,  8.34977801,
#        12.20257107, 11.56007129,  9.65008341,  8.27509241, 14.5379702 ,
#        12.95625771, 13.97960116,  6.59903485,  8.92884359,  9.1499757 ,
#         5.90335878, 10.40647779,  7.05782835,  7.79379525,  4.921134  ,
#         9.53277646,  6.83203849, 10.49802006,  9.70927581,  6.01565994,
#        11.2111626 , 14.55114604, 10.97238181,  8.48281601, 10.0939514 ,
#         6.5436607 , 14.32280958, 12.26543243,  9.65567456, 13.4038409 ,
#         5.56559704,  8.61569067,  9.20192445, 11.09045155, 10.5002698 ,
#        12.30855776,  6.78487588, 13.7839155 , 12.00233732,  5.19954542,
#        14.25368816,  9.94064199,  9.57431969, 10.09738696,  3.49657914,
# ...

# %% [markdown]
# ## Linear regression 모델 훈련
#
# ## Scikit-learn 라이브러리의 LinearRegression() 사용

# %%
from sklearn.linear_model import LinearRegression

# 선형회귀 모델
model = LinearRegression()

# 모델 훈련
model.fit(x, y)
# Out:
# LinearRegression()

# %%
print('y 절편(b):', model.intercept_)
print('회귀계수(w):', model.coef_)
# Out:
# y 절편(b): 5.811834725789672
# 회귀계수(w): [1.85583546]

# %%
# 예측
y_pred = model.predict(x) 

# 선형 회귀선 그리기
plt.scatter(x, y)
plt.plot(x, y_pred)
